# %% [markdown]
# # **Árboles de regresión**

# %% [markdown]
# ## **¿Qué es esto?**

# %% [markdown]
# Se aplican cuando la variable de respuesta es continua, por ejemplo altura, peso, precio etc.

# %% [markdown]
# Entonces, ¿qué es esto y qué hace?. A ver, el programa coge los datos de train y les hace preguntas como si fuera la CIA para poder clasificar los datos. A partir de esas preguntas crea un árbol de decisión como el de la foto de abajo. Cada pregunta nueva, es un nodo más del árbol.
#
# <img src=https://www.maximaformacion.es/wp-content/uploads/2020/05/Estructura-de-un-%C3%A1rbol-de-decisi%C3%B3n.jpg alt="drawing" style="width:350px;"/>

# %% [markdown]
# Si no haces que pare puede crear ramas pa' aburrir. Ya veremos luego pero esto tampoco es dejarlo que cree ramas sin talento. Hay que pararlo en algún punto.

# %% [markdown]
# Pa' este ejercicio vamos a usar el Boston dataset (que está mas trillao que el copón...). Vamos a dejar de hacer código complejo y hacemos codigo que se le pueda dar al enter y haga algo.

# %% [markdown]
# Por cierto, la web de la que saco todo esto es www.cienciadedatos.net

# %% [markdown]
# ## **Empezamos**

# %% [markdown]
# 1. Importa todas las sheits necesarias para hacer un árbol mejor que el de Navidad que pones en tu casa (que seguro que no lo pones por pereza, perro)

# %%
# Tratamiento de datos
# ------------------------------------------------------------------------------
import numpy as np
import pandas as pd

# Gráficos
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt

# Preprocesado y modelado
# ------------------------------------------------------------------------------
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz
from sklearn.tree import export_text
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

# Configuración warnings
# ------------------------------------------------------------------------------
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Hemos importado el dataset típico de casas de Boston

# %% [markdown]
# 2. Pilla to' los datos y mételos en un dataframe. El dataset este esta separao las variables y el target pero nos interesa tenerlo todo junto. Mierdas raras. Tu copia y pega que en un csv normal no pasan estas cosas

# %%
# Se unen todos los datos (predictores y variable respuesta en un único dataframe)
boston = load_boston(return_X_y=False)
datos = np.column_stack((boston.data, boston.target))
datos = pd.DataFrame(datos,columns = np.append(boston.feature_names, "MEDV"))
datos.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# **Lo de siempre, a dividir en train y test**

# %%
# División de los datos en train y test
# ------------------------------------------------------------------------------
X_train, X_test, y_train, y_test = train_test_split(
                                        datos.drop(columns = "MEDV"),
                                        datos['MEDV'],
                                        random_state = 123
                                    )
# Creación del modelo
# ------------------------------------------------------------------------------
modelo = DecisionTreeRegressor(
            max_depth         = 3,
            random_state      = 123
          )

# Entrenamiento del modelo
# ------------------------------------------------------------------------------
modelo.fit(X_train, y_train)
# Out:
# C:\Users\serra\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# DecisionTreeRegressor(max_depth=3, random_state=123)
