# %% [markdown]
# ## **2.Regresión polinómica**

# %% [markdown]
# **Antes de hacer la regresión polinómica se tiene que hacer una regresión lineal y ver que no es apta para lo que queremos predecir, por ello no se van a crear las X ni las y en este notebook. Ya se crean en el anterior notebook de regresión lineal.**

# %% [markdown]
# Una regresión polinómica **trata de añadirle complejidad a la regresión lineal para poder ajustarte mejor a tu modelo cuando la regresión lineal es insuficiente.**

# %% [markdown]
# Para empezar, importamos el objeto "PolynomialFeatures" para poder hacer la regresión polinómica

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# **Creamos el objeto de regresión polinómica** con el número de grados que queremos que haga. **Con más de 4 grados tenemos una posibilidad muy alta de caer en sobreoptimización** (overfitting pa los flipaos)

# %%
poly_reg = PolynomialFeatures(degree=3)

# %% [markdown]
# Entrenamos nuestra regresión polinómica

# %%
poly_reg.fit(X)

# %% [markdown]
# Aplicamos la transformación que nos permitirá graficar todo más adelante como si fuese una regresión lineal normal

# %%
X_poly = poly_reg.transform(X)

# %% [markdown]
# **Creamos el objeto de regresión lineal** con las variables ya transformadas

# %%
pol_reg = LinearRegression()

# %% [markdown]
# **Entrenamos esta nueva regresión lineal con los coeficientes transformados**

# %%
pol_reg.fit(X_poly, y)

# %% [markdown]
# **Calculamos $r ^ 2$**
#
# $r^2$ nos indica que tan bien se ajusta nuestro modelo a la recta de regresión.
#
#     Cercano a 1 --> Buena mierda. Aunque a partir de 0.9 puede ser un overfitting de cuidao
#
#     Cercano a 0 --> Not good sheit
#
#    <img src=https://miro.medium.com/max/1472/0*8rFYfZJfJZpW2cEV.png alt="drawing" style="width:350px;"/>

# %%
lm.score(X_train_scal, y_train) * 100 # Entrenamiento
lm.score(X_test_scal, y_test) * 100  # Test

# %% [markdown]
# Entrenamiento y test tienen que dar más o menos parecido, sino has hecho un churro de puta madre, revisa.

# %% [markdown]
# **Visualizamos los resultados de la regresión polinómica**

# %%
def viz_polymonial():
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.transform(X)), color='blue')
    plt.title('Truth or Bluff (Linear Regression)')
    plt.xlabel('Position level')
    plt.ylabel('Salary')
    plt.show()
    return
viz_polymonial()
